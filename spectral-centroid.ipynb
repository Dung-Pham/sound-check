# %% [markdown]
# # Trích xuất đặc trưng spectral-centroid

# %% [markdown]
# ## Thư viện

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 7]

plt.plot(x, y)
plt.title("Đồ thị đơn giản")
plt.show()

# %% [markdown]
# ## Thư viện 2
